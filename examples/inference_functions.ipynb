# %%
from equinet.inference import predict_vle_single_point, predict_vle_isothermal_envelope, predict_vle_isobaric_envelope, predict_vle_parameters

# %%
predict_vle_single_point(
    smiles_1="CCO",
    smiles_2="CCN",
    x1=0.5,
    x2=0.5,
    temperature=298.15)
# Out:
# {'x1': 0.05467696860432625,
#  'x2': 0.9453230500221252,
#  'T': 4.715011119842529,
#  'lngamma1': -0.3374776840209961,
#  'lngamma2': -0.33623406291007996,
#  'log10P1sat': 3.9004104137420654,
#  'log10P2sat': 5.137646198272705}

# %%
predict_vle_isothermal_envelope(
    smiles_1="CCO",
    smiles_2="CCN",
    temperature=298.15,
    mesh_size=5,
)
# Out:
# {'x1': array([0.        , 0.00982609, 0.05467697, 0.25250143, 1.        ]),
#  'x2': array([1.        , 0.99017394, 0.94532305, 0.74749857, 0.        ]),
#  'T': array([5.1376462 , 4.9789257 , 4.71501112, 4.33489037, 3.90041041]),
#  'lngamma1': array([-1.37986267, -0.75304699, -0.33747768, -0.08822929,  0.        ]),
#  'lngamma2': array([ 0.        , -0.08766009, -0.33623403, -0.75314212, -1.38414824]),
#  'log10P1sat': array([3.90041041, 3.90041041, 3.90041041, 3.90041041, 3.90041041]),
#  'log10P2sat': array([5.1376462, 5.1376462, 5.1376462, 5.1376462, 5.1376462])}

# %%
predict_vle_isobaric_envelope(
    smiles_1="CCO",
    smiles_2="CCCCN",
    pressure=101325,
    mesh_size=5,
)
# Out:
# {'x1': array([0.        , 0.16149446, 0.47942832, 0.8293978 , 1.        ]),
#  'x2': array([1.        , 0.83850557, 0.52057171, 0.1706022 , 0.        ]),
#  'T': array([5.0057168, 5.0057168, 5.0057168, 5.0057168, 5.0057168]),
#  'lngamma1': array([-0.90534961, -0.58201849, -0.30732238, -0.09314105,  0.        ]),
#  'lngamma2': array([ 0.        , -0.04682951, -0.21530202, -0.57974082, -1.26321733]),
#  'log10P1sat': array([4.98304796, 5.06870174, 5.12093925, 5.08986902, 5.0057168 ]),
#  'log10P2sat': array([5.0057168 , 5.07449913, 5.11673212, 5.09153938, 5.02411366])}

# %%
predict_vle_parameters(
    smiles_1="CCO",
    smiles_2="CCN",
    temperature=298.15
)
# Out:
# {'tau_12': np.float64(-0.291841596364975),
#  'tau_21': np.float64(-1.0154340267181396),
#  'alpha': np.float64(0.5708988904953003),
#  'antoine_a_1': np.float64(-5.948912654066621),
#  'antoine_b_1': np.float64(116.79163743794996),
#  'antoine_c_1': np.float64(-134.06400053713034),
#  'antoine_a_2': np.float64(-4.767724920058786),
#  'antoine_b_2': np.float64(-100.46683757531956),
#  'antoine_c_2': np.float64(17.421458808813014)}
